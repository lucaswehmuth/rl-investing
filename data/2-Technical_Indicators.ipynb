# %% [markdown]
# # 1 - ta
# https://github.com/bukosabino/ta

# %%
import pandas as pd
from ta import add_all_ta_features
from ta.utils import dropna

# %%
# Load datas
df = pd.read_csv('AAPL.csv', sep=',')

# Clean NaN values
df = dropna(df)

# Add ta features filling NaN values
df = add_all_ta_features(df, open="open", high="high", low="low", close="close", volume="volume", fillna=True)
# Out:
# /Users/Lucas/opt/miniconda3/envs/ds/lib/python3.7/site-packages/ta/trend.py:768: RuntimeWarning: invalid value encountered in double_scalars
#   dip[i] = 100 * (self._dip[i] / self._trs[i])
# /Users/Lucas/opt/miniconda3/envs/ds/lib/python3.7/site-packages/ta/trend.py:772: RuntimeWarning: invalid value encountered in double_scalars
#   din[i] = 100 * (self._din[i] / self._trs[i])

# %%
df
# Out:
#                      date        open        high         low       close  \
# 0     1999-12-31 00:00:00    0.901228    0.918527    0.888393    0.917969
# 1     2000-01-03 00:00:00    0.936384    1.004464    0.907924    0.999442
# 2     2000-01-04 00:00:00    0.966518    0.987723    0.903460    0.915179
# 3     2000-01-05 00:00:00    0.926339    0.987165    0.919643    0.928571
# 4     2000-01-06 00:00:00    0.947545    0.955357    0.848214    0.848214
# ...                   ...         ...         ...         ...         ...
# 5280  2020-12-24 00:00:00  131.320007  133.460007  131.100006  131.970001
# 5281  2020-12-28 00:00:00  133.990005  137.339996  133.509995  136.690002
# 5282  2020-12-29 00:00:00  138.050003  138.789993  134.339996  134.869995
# 5283  2020-12-30 00:00:00  135.580002  135.990005  133.399994  133.720001
# 5284  2020-12-31 00:00:00  134.080002  134.740005  131.720001  132.690002
#
#        adj_close     volume    volume_adi    volume_obv  volume_cmf  ...  \
# 0       0.791887  163811200  1.577443e+08     163811200    0.962964  ...
# 1       0.862170  535796800  6.377938e+08     699608000    0.911645  ...
# 2       0.789479  512377600  2.679319e+08     187230400    0.221069  ...
# 3       0.801033  778321600 -3.045533e+08     965552000   -0.153018  ...
# 4       0.731713  767972800 -1.072526e+09     197579200   -0.388839  ...
# ...          ...        ...           ...           ...         ...  ...
# 5280  131.970001   54930100  7.783073e+10  102082553000    0.118079  ...
# 5281  136.690002  124486200  7.791296e+10  102207039200    0.160608  ...
# 5282  134.869995  121047300  7.782075e+10  102085991900    0.114788  ...
# 5283  133.720001   96452100  7.774813e+10  101989539800    0.047229  ...
# 5284  132.690002   98990400  7.771273e+10  101890549400   -0.002191  ...
#
#       momentum_wr  momentum_ao  momentum_kama  momentum_roc  momentum_ppo  \
# 0       -1.851797     0.000000       0.917969      0.000000      0.000000
# 1       -4.326895     0.000000       0.951172      0.000000     15.506471
# 2      -76.923057     0.000000       0.936171      0.000000     23.573295
# 3      -65.384637     0.000000       0.932840      0.000000     34.197412
# 4     -100.000000     0.000000       0.896210      0.000000     39.053331
# ...           ...          ...            ...           ...           ...
# 5280   -17.110814     8.041295     125.756798      6.102271      0.139209
# 5281    -3.781234     9.081940     128.096537     12.243393      1.309441
# 5282   -21.030042    10.702911     129.237246      9.436869      1.946265
# 5283   -27.199540    10.681940     129.544099      9.239439      0.656953
# 5284   -33.442950    10.560030     129.697497      8.958781     -0.190793
#
#       momentum_ppo_signal  momentum_ppo_hist  others_dr  others_dlr  \
# 0                0.000000           0.000000 -95.097775    0.000000
# 1                3.101294          12.405177   8.875382    8.503376
# 2                7.195694          16.377601  -8.431043   -8.807787
# 3               12.596038          21.601374   1.463409    1.452805
# 4               17.887497          21.165835  -8.653845   -9.051400
# ...                   ...                ...        ...         ...
# 5280             0.974077          -0.834868   0.771224    0.768265
# 5281             1.041150           0.268291   3.576571    3.514097
# 5282             1.222173           0.724092  -1.331485   -1.340429
# 5283             1.109129          -0.452175  -0.852668   -0.856324
# 5284             0.849144          -1.039938  -0.770265   -0.773247
#
#          others_cr
# 0         0.000000
# 1         8.875382
# 2        -0.303949
# 3         1.155012
# 4        -7.598786
# ...            ...
# 5280  14276.306516
# 5281  14790.485372
# 5282  14592.220745
# 5283  14466.944814
# 5284  14354.740691
#
# [5285 rows x 90 columns]

# %% [markdown]
# # 2 - pandas-ta
# https://github.com/twopirllc/pandas-ta

# %%
import pandas_ta as pd_ta
